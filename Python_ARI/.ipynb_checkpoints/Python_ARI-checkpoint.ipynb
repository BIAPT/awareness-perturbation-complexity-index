# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from scipy.stats import pearsonr, kendalltau

# %%
#data_dir = 'RESULTS/WSAS/ARI_3states_alpha.txt'
data_dir = 'RESULTS/WSAS/2state_ARI_Base_Anes_alpha.txt'
patient_information = 'DATA/data_original/data_2states.txt'

#data_dir = 'RESULTS/WSAS_new/ARI_max_2states_alpha.txt'
#patient_information = 'DATA/continuous_derivative_WSAS/data_dyn_states.txt'

#data_dir = 'RESULTS/NETICU/2state_ARI_Sedon1_Sedoff_alpha.txt'
#patient_information = 'DATA/NET-ICU_derivative_standard/data_2states.txt'

# %%
# load patient info
info = pd.read_csv(patient_information, sep = '\t')
info
# Out:
#    Patient  Diag Age Sex  Injury   TSI    State  CRSR Outcome_Diag Group_Diag  \
# 0   WSAS02   UWS  29   M     TBI     -    Acute     4            1        UWS
# 1   WSAS05   MCS  28   M     TBI   9 Y  Chronic    10            2        MCS
# 2   WSAS09   UWS  50   F  Stroke  25 D    Acute     4            1        UWS
# 3   WSAS10   UWS  75   F  Stroke   NaN    Acute     5            1        UWS
# 4   WSAS11   UWS  28   F  Anoxic    1Y  Chronic     6            1        UWS
# 5   WSAS12   MCS  36   F     TBI    2Y  Chronic    11            2        MCS
# 6   WSAS13   UWS  24   M  Anoxic    8Y  Chronic     5            1        UWS
# 7   WSAS17  Coma  74   F  Anoxic   10D    Acute     0            0       Coma
# 8   WSAS18   UWS  53   F  Anoxic    9M  Chronic     5            1        UWS
# 9   WSAS19  Coma  40   M  Stroke    5D    Acute     0            0       Coma
# 10  WSAS20   UWS  42   F  Stroke   20D    Acute     3            1        UWS
# 11  WSAS22   UWS  18   F     TBI   20D    Acute     5            1        UWS
# 12  WSAS25   UWS  66   M     ICH    3D    Acute     2            1        UWS
# 13  WSAS27   UWS  38   F     ICH   24D    Acute     5            1        UWS
# 14  WSAS28   MCS  38   F     ICH   23D    Acute     7            2        MCS
# 15  WSAS29  Coma  74   F     ICH   33D    Acute     0            0       Coma
# 16  WSAS31     -   -   M       -     -    Acute     5            -          -
#
#     Outcome_Prog          Group_Prog
# 0              1           Recovered
# 1              0       Non-recovered
# 2              1           Recovered
# 3              0       Non-recovered
# 4              0       Non-recovered
# 5              0       Non-recovered
# 6              0       Non-recovered
# 7              0       Non-recovered
# 8              0       Non-recovered
# 9              3  WOC, Suspected LIS
# 10             1           Recovered
# 11             0       Non-recovered
# 12             0       Non-recovered
# 13             1           Recovered
# 14             1           Recovered
# 15             0       Non-recovered
# 16             4         NEW PATIENT

# %%
# load data
features = pd.read_csv(data_dir, sep = ',')
features['ARI'] = features['Hub_ARI'] + features['dPLI_ARI']
features
# Out:
#         ID  dPLI_ARI   Hub_ARI  dirhub_ARI       ARI
# 0   WSAS02  0.026312  1.235972    0.194829  1.262285
# 1   WSAS05  0.019862  1.145439    0.331827  1.165301
# 2   WSAS09  0.065431  1.075923    1.352848  1.141354
# 3   WSAS10  0.024221  1.020861    0.357689  1.045081
# 4   WSAS11  0.023570  1.116612    0.412443  1.140181
# 5   WSAS12  0.023890  0.905420    0.458246  0.929310
# 6   WSAS13  0.023967  0.815346    0.445385  0.839313
# 7   WSAS17  0.017042  0.815962    0.171083  0.833004
# 8   WSAS18  0.019688  1.127676    0.457895  1.147364
# 9   WSAS19  0.052467  1.025169    1.473359  1.077635
# 10  WSAS20  0.026574  1.137479    0.662575  1.164053
# 11  WSAS22  0.018033  0.681887    0.382020  0.699920
# 12  WSAS25  0.015587  1.052380    0.609471  1.067967
# 13  WSAS27  0.031107  1.067179    1.195994  1.098287
# 14  WSAS28  0.040103  1.208406    1.222233  1.248508
# 15  WSAS29  0.013035  0.949283    0.317966  0.962319
# 16  WSAS31  0.053201  1.104542    0.813470  1.157743

# %%
data = pd.concat([info, features], axis = 1)
data_outcome = data[data['Group_Prog']!='Unknown']

# %%
plt.figure(figsize = (7,5))
sns.scatterplot(y = 'Hub_ARI', x = 'dPLI_ARI', data = data, hue='Group_Prog',style="State", s = 100)

plt.ylabel('Hub Reconfiguration', fontsize = 12)
plt.xlabel('dPLI Reconfiguration', fontsize = 12)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.legend(fontsize = 10)

for i  in range(len(data)):
    plt.annotate(data['ID'][i][-2:], (data['dPLI_ARI'][i], data['Hub_ARI'][i]), fontsize = 8)

#plt.title('2-state ARI [Pre-Anesthesia/Anesthesia]\n', fontsize = 20)

# %%
plt.figure(figsize = (8,5))
sns.scatterplot(x = 'dPLI_ARI', y = 'Hub_ARI', data = data, hue='Group_Prog', s = 100)

plt.ylabel('wPLI Hub Reconfiguration', fontsize = 20)
plt.xlabel('dPLI Hub Reconfiguration', fontsize = 20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.legend(fontsize = 15)

for i  in range(len(data)):
    plt.annotate(data['ID'][i][-2:], (data['dPLI_ARI'][i], data['Hub_ARI'][i]), fontsize = 10)

# %%
sns.boxplot(y = 'ARI', x = 'Group_Prog', data = data_outcome)
sns.scatterplot(y = 'ARI', x = 'Group_Prog', data = data_outcome, color ='black', s = 50)
# Out:
# <AxesSubplot: xlabel='Group_Prog', ylabel='ARI'>

# %%
sns.boxplot(y = 'Hub_ARI', x = 'Group_Prog', data = data_outcome)
sns.scatterplot(y = 'Hub_ARI', x = 'Group_Prog', data = data_outcome, color ='black', s = 50)
# Out:
# <AxesSubplot: xlabel='Group_Prog', ylabel='Hub_ARI'>
